# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import re
import seaborn as sns
import statistics

# %%
plt.style.use('ggplot')
sns.set(font='Arial',
    rc={
        'font.size' : 12,
        'axes.titlesize' : 24,
        'axes.axisbelow': False,
        'axes.edgecolor': 'lightgrey',
        'axes.facecolor': 'None',
        'axes.grid': False,
        'axes.labelcolor': 'dimgrey',
        'axes.spines.right': False,
        'axes.spines.top': False,
        'figure.facecolor': 'white',
        'lines.solid_capstyle': 'round',
        'patch.edgecolor': 'w',
        'patch.force_edgecolor': True,
        'text.color': 'black',
        'xtick.bottom': False,
        'xtick.color': 'dimgrey',
        'xtick.direction': 'out',
        'xtick.top': False,
        'ytick.color': 'dimgrey',
        'ytick.direction': 'out',
        'ytick.left': False,
        'ytick.right': False})
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
with open("/home/nvankampen/plasma-umass/custom/boxed-sim/detector.out") as f:
    data = json.load(f)

# %%
fig, ax = plt.subplots()
x = data["SizeClasses"][:35]
y = data["Bins"][:35]
plt.xticks(rotation=90)
ax.set_title("Size class distribution for boxed-sim", pad=20, fontweight='bold', font="Arial", fontsize=18)
ax.set_xlabel("Size class bins")
ax.set_ylabel("Number of recorded allocations")
fig.tight_layout()
ax.bar(np.arange(35), y, tick_label=x, log=True)
plt.savefig("AllocationDistribution.boxed-sim.png")
